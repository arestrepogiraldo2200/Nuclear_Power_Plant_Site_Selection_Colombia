# %%
import geopandas as gpd
import json

# %%
df = gpd.read_file('./RiesgoInundaciones/Inundacion_50TR.shp')
df = df.to_crs(crs=4326)
df
# Out:
#         Id  gridcode     Shape_Leng    Shape_Area  \
# 0        9         2    3708.860800  6.234973e+05
# 1       12         2   39638.014456  4.103335e+07
# 2       24         2   43504.971405  4.161725e+07
# 3       31         2    3949.696819  9.749514e+05
# 4       32         2   13811.018133  8.776634e+06
# ...    ...       ...            ...           ...
# 2722  5238         2   14272.765516  5.801735e+06
# 2723  5240         2   18234.406616  1.146174e+07
# 2724  5246         2  194663.626049  2.140944e+08
# 2725  5256         2    3991.236088  9.956189e+05
# 2726  5259         2   74196.630658  1.210054e+08
#
#                                                geometry
# 0     POLYGON ((-71.40865 12.37902, -71.39965 12.379...
# 1     POLYGON ((-71.44465 12.37902, -71.42665 12.379...
# 2     POLYGON ((-71.76865 12.12702, -71.78363 12.130...
# 3     POLYGON ((-72.35365 11.83002, -72.35365 11.839...
# 4     POLYGON ((-72.33565 11.78502, -72.32665 11.785...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>
